# %%
# !pip install transformers requests

# %%
from transformers import pipeline,Conversation

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
generator = pipeline("sentiment-analysis", model='finiteautomata/bertweet-base-sentiment-analysis')
# Out:
# config.json:   0%|          | 0.00/949 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
print("chatbot:I am a generator bot.i will analyse your emotions ")
input_text = input("You: ")
exit_words= ["bye","exit","quit"]
while input_text not in exit_words:
  print(generator(input_text))
  input_text = input("You: "  )
# Out:
# chatbot:I am a generator bot.i will analyse your emotions
# You: hi'
# [{'label': 'NEU', 'score': 0.9363557696342468}]
# You: what are you doing
# [{'label': 'NEU', 'score': 0.955247163772583}]
# You: what is your good name
# [{'label': 'NEU', 'score': 0.7203152775764465}]
# You: i am mad at you
# [{'label': 'NEG', 'score': 0.9714291095733643}]
# You: exit
